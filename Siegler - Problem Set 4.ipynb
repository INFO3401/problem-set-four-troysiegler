# %%
# 1

# I had originally anticipated that former candidate, Andrew Yang, was going to win the election
# After Yang Dropped out, I believed that Joe Biden would win the nomination due to the fact that he has
# a ton of experience in politics and he apeals to a large range of people (former obama supporters)

# I believe that Joe Biden and Donald Trump will be our two candidates for President later this year

# %%
from rcp import get_polls, get_poll_data
from pprint import pprint
import pandas as pd
import pprint as pprint
import matplotlib.pyplot as plt

# %%
# 2 (terminal)

# Troys-MacBook-Pro:~ troysiegler$ pip install realclearpolitics (done in terminal)

# Requirement already satisfied: realclearpolitics in ./anaconda3/lib/python3.6/site-packages (1.2.1)
# Requirement already satisfied: requests in ./anaconda3/lib/python3.6/site-packages (from realclearpolitics) (2.22.0)
# Requirement already satisfied: beautifulsoup4 in ./anaconda3/lib/python3.6/site-packages (from realclearpolitics) (4.7.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in ./anaconda3/lib/python3.6/site-packages (from requests->realclearpolitics) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in ./anaconda3/lib/python3.6/site-packages (from requests->realclearpolitics) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.6/site-packages (from requests->realclearpolitics) (2019.6.16)
# Requirement already satisfied: idna<2.9,>=2.5 in ./anaconda3/lib/python3.6/site-packages (from requests->realclearpolitics) (2.8)
# Requirement already satisfied: soupsieve>=1.2 in ./anaconda3/lib/python3.6/site-packages (from beautifulsoup4->realclearpolitics) (1.8)
# Troys-MacBook-Pro:~ troysiegler$ 

#Troys-MacBook-Pro:COVID-19 troysiegler$ rcp https://www.realclearpolitics.com/epolls/2020/president/us/2020_democratic_presidential_nomination-6730.html
#Downloading: 2020_democratic_presidential_nomination-6730.csv
#CSV created.
#Troys-MacBook-Pro:COVID-19 troysiegler$

# %%
# 3
# opening the file (deleted RCP average in excel)

democrat = pd.read_csv("2020_democratic_presidential_nomination-6730.csv")
democrat
# Out:
#                                 Poll         Date    Sample  Biden  Sanders  \
# 0             Economist/YouGovYouGov  3/29 - 3/31    573 LV     55       40
# 1           The Hill/HarrisXThe Hill  3/29 - 3/30    425 RV     54       32
# 2          Morning ConsultM. Consult  3/23 - 3/29  15101 RV     61       36
# 3               Harvard-HarrisHarris  3/24 - 3/26    903 RV     58       32
# 4           ABC News/Wash PostABC/WP  3/22 - 3/25    388 RV     55       39
# 5             Economist/YouGovYouGov  3/22 - 3/24    547 LV     57       39
# 6               Reuters/IpsosReuters  3/18 - 3/24   1981 RV     53       34
# 7          Morning ConsultM. Consult  3/16 - 3/22  16180 LV     60       36
# 8                     EmersonEmerson  3/18 - 3/19    519 RV     54       42
# 9             Economist/YouGovYouGov  3/15 - 3/17    551 LV     57       36
# 10              Reuters/IpsosReuters  3/13 - 3/16    458 RV     48       39
# 11          The Hill/HarrisXThe Hill  3/14 - 3/15    894 RV     55       31
# 12  Politico/Morning ConsultPolitico  3/11 - 3/15   8869 LV     58       37
# 13     NBC News/Wall St. JrnlNBC/WSJ  3/11 - 3/13    438 LV     61       32
# 14  Politico/Morning ConsultPolitico  3/11 - 3/11   2072 LV     59       35
# 15            Economist/YouGovYouGov   3/8 - 3/10    573 RV     53       38
# 16          The Hill/HarrisXThe Hill    3/8 - 3/9    442 RV     55       28
# 17              Reuters/IpsosReuters    3/6 - 3/9    420 RV     54       33
# 18              QuinnipiacQuinnipiac    3/5 - 3/8    559 RV     54       35
# 19  Politico/Morning ConsultPolitico    3/5 - 3/8   9593 RV     56       38
# 20                            CNNCNN    3/4 - 3/7    540 RV     52       36
# 21  Politico/Morning ConsultPolitico    3/5 - 3/5   1390 LV     54       38
# 22              Reuters/IpsosReuters    3/4 - 3/5    474 RV     45       32
# 23  Politico/Morning ConsultPolitico    3/2 - 3/3    961 LV     36       28
# 24            Economist/YouGovYouGov    3/1 - 3/3    722 RV     28       24
# 25          The Hill/HarrisXThe Hill    3/1 - 3/2    449 RV     28       23
# 26  Politico/Morning ConsultPolitico    3/1 - 3/1   2656 LV     26       29
# 27              Reuters/IpsosReuters   2/28 - 3/2    469 RV     18       29
# 28              Harvard-HarrisHarris  2/26 - 2/28    980 RV     20       25
# 29         Yahoo News/YouGov*YouGov*  2/26 - 2/27    811 RV     21       27
# 30  Politico/Morning ConsultPolitico  2/26 - 2/27   5334 LV     21       33
# 31                  IBD/TIPPIBD/TIPP  2/20 - 2/29    325 RV     20       23
# 32                  FOX NewsFOX News  2/23 - 2/26    507 LV     18       31
# 33            Economist/YouGovYouGov  2/23 - 2/25    584 RV     20       30
# 34          The Hill/HarrisXThe Hill  2/23 - 2/24    470 RV     17       28
# 35              Reuters/IpsosReuters  2/19 - 2/25   1808 RV     17       29
# 36           CBS News/YouGovCBS News  2/20 - 2/22   6498 LV     17       28
# 37                    EmersonEmerson  2/16 - 2/18    573 LV     22       29
# 38            Economist/YouGovYouGov  2/16 - 2/18    555 LV     18       24
# 39          ABC News/Wash PostABC/WP  2/14 - 2/17    408 RV     16       32
# 40     NBC News/Wall St. JrnlNBC/WSJ  2/14 - 2/17    426 LV     15       27
# 41              Reuters/IpsosReuters  2/14 - 2/17    385 RV     15       28
# 42                     SurveyUSASUSA  2/13 - 2/17   1022 LV     18       29
# 43             NPR/PBS/MaristNPR/PBS  2/13 - 2/16    527 RV     15       31
# 44          The Hill/HarrisXThe Hill  2/14 - 2/15    449 RV     19       22
# 45  Politico/Morning ConsultPolitico  2/12 - 2/17  15974 RV     19       28
# 46            Economist/YouGovYouGov   2/9 - 2/11    552 LV     18       22
# 47          The Hill/HarrisXThe Hill   2/7 - 2/10    913 RV     23       20
#
#          Spread
# 0     Biden +15
# 1     Biden +22
# 2     Biden +25
# 3     Biden +26
# 4     Biden +16
# 5     Biden +18
# 6     Biden +19
# 7     Biden +24
# 8     Biden +12
# 9     Biden +21
# 10     Biden +9
# 11    Biden +24
# 12    Biden +21
# 13    Biden +29
# 14    Biden +24
# 15    Biden +15
# 16    Biden +27
# 17    Biden +21
# 18    Biden +19
# 19    Biden +18
# 20    Biden +16
# 21    Biden +16
# 22    Biden +13
# 23     Biden +8
# 24     Biden +4
# 25     Biden +5
# 26   Sanders +3
# 27  Sanders +11
# 28   Sanders +5
# 29   Sanders +6
# 30  Sanders +12
# 31   Sanders +3
# 32  Sanders +13
# 33  Sanders +10
# 34   Sanders +9
# 35  Sanders +12
# 36   Sanders +9
# 37   Sanders +7
# 38   Sanders +6
# 39  Sanders +16
# 40  Sanders +12
# 41  Sanders +11
# 42  Sanders +11
# 43  Sanders +12
# 44   Sanders +3
# 45   Sanders +8
# 46   Sanders +4
# 47     Biden +3

# %%
# 3 (continued)

# observations about the data

# 1: Sanders and Biden are currently the two front runners
# 2: Sanders has the highest spreads over all of the different types of poles
# 3: Gabbard is the lowest out of all the current candidates

# %%
# 4 

def loadAndCleanData(file):
    lCFile = pd.read_csv(file)
    lCFile.fillna(value = 0, inplace = True)
    return lCFile

cleanFile = loadAndCleanData("2020_democratic_presidential_nomination-6730.csv")

# %%
# 5

def normalizeData(file):
    undecided = []
    for i,v in file.iterrows():
        undecided.append((100 - (v[3] + v[4])))
        
    file["Undecided"] = undecided
    return file

# %%
#6

normalizeData(democrat)
# Out:
#                                 Poll         Date    Sample  Biden  Sanders  \
# 0             Economist/YouGovYouGov  3/29 - 3/31    573 LV     55       40
# 1           The Hill/HarrisXThe Hill  3/29 - 3/30    425 RV     54       32
# 2          Morning ConsultM. Consult  3/23 - 3/29  15101 RV     61       36
# 3               Harvard-HarrisHarris  3/24 - 3/26    903 RV     58       32
# 4           ABC News/Wash PostABC/WP  3/22 - 3/25    388 RV     55       39
# 5             Economist/YouGovYouGov  3/22 - 3/24    547 LV     57       39
# 6               Reuters/IpsosReuters  3/18 - 3/24   1981 RV     53       34
# 7          Morning ConsultM. Consult  3/16 - 3/22  16180 LV     60       36
# 8                     EmersonEmerson  3/18 - 3/19    519 RV     54       42
# 9             Economist/YouGovYouGov  3/15 - 3/17    551 LV     57       36
# 10              Reuters/IpsosReuters  3/13 - 3/16    458 RV     48       39
# 11          The Hill/HarrisXThe Hill  3/14 - 3/15    894 RV     55       31
# 12  Politico/Morning ConsultPolitico  3/11 - 3/15   8869 LV     58       37
# 13     NBC News/Wall St. JrnlNBC/WSJ  3/11 - 3/13    438 LV     61       32
# 14  Politico/Morning ConsultPolitico  3/11 - 3/11   2072 LV     59       35
# 15            Economist/YouGovYouGov   3/8 - 3/10    573 RV     53       38
# 16          The Hill/HarrisXThe Hill    3/8 - 3/9    442 RV     55       28
# 17              Reuters/IpsosReuters    3/6 - 3/9    420 RV     54       33
# 18              QuinnipiacQuinnipiac    3/5 - 3/8    559 RV     54       35
# 19  Politico/Morning ConsultPolitico    3/5 - 3/8   9593 RV     56       38
# 20                            CNNCNN    3/4 - 3/7    540 RV     52       36
# 21  Politico/Morning ConsultPolitico    3/5 - 3/5   1390 LV     54       38
# 22              Reuters/IpsosReuters    3/4 - 3/5    474 RV     45       32
# 23  Politico/Morning ConsultPolitico    3/2 - 3/3    961 LV     36       28
# 24            Economist/YouGovYouGov    3/1 - 3/3    722 RV     28       24
# 25          The Hill/HarrisXThe Hill    3/1 - 3/2    449 RV     28       23
# 26  Politico/Morning ConsultPolitico    3/1 - 3/1   2656 LV     26       29
# 27              Reuters/IpsosReuters   2/28 - 3/2    469 RV     18       29
# 28              Harvard-HarrisHarris  2/26 - 2/28    980 RV     20       25
# 29         Yahoo News/YouGov*YouGov*  2/26 - 2/27    811 RV     21       27
# 30  Politico/Morning ConsultPolitico  2/26 - 2/27   5334 LV     21       33
# 31                  IBD/TIPPIBD/TIPP  2/20 - 2/29    325 RV     20       23
# 32                  FOX NewsFOX News  2/23 - 2/26    507 LV     18       31
# 33            Economist/YouGovYouGov  2/23 - 2/25    584 RV     20       30
# 34          The Hill/HarrisXThe Hill  2/23 - 2/24    470 RV     17       28
# 35              Reuters/IpsosReuters  2/19 - 2/25   1808 RV     17       29
# 36           CBS News/YouGovCBS News  2/20 - 2/22   6498 LV     17       28
# 37                    EmersonEmerson  2/16 - 2/18    573 LV     22       29
# 38            Economist/YouGovYouGov  2/16 - 2/18    555 LV     18       24
# 39          ABC News/Wash PostABC/WP  2/14 - 2/17    408 RV     16       32
# 40     NBC News/Wall St. JrnlNBC/WSJ  2/14 - 2/17    426 LV     15       27
# 41              Reuters/IpsosReuters  2/14 - 2/17    385 RV     15       28
# 42                     SurveyUSASUSA  2/13 - 2/17   1022 LV     18       29
# 43             NPR/PBS/MaristNPR/PBS  2/13 - 2/16    527 RV     15       31
# 44          The Hill/HarrisXThe Hill  2/14 - 2/15    449 RV     19       22
# 45  Politico/Morning ConsultPolitico  2/12 - 2/17  15974 RV     19       28
# 46            Economist/YouGovYouGov   2/9 - 2/11    552 LV     18       22
# 47          The Hill/HarrisXThe Hill   2/7 - 2/10    913 RV     23       20
#
#          Spread  Undecided
# 0     Biden +15          5
# 1     Biden +22         14
# 2     Biden +25          3
# 3     Biden +26         10
# 4     Biden +16          6
# 5     Biden +18          4
# 6     Biden +19         13
# 7     Biden +24          4
# 8     Biden +12          4
# 9     Biden +21          7
# 10     Biden +9         13
# 11    Biden +24         14
# 12    Biden +21          5
# 13    Biden +29          7
# 14    Biden +24          6
# 15    Biden +15          9
# 16    Biden +27         17
# 17    Biden +21         13
# 18    Biden +19         11
# 19    Biden +18          6
# 20    Biden +16         12
# 21    Biden +16          8
# 22    Biden +13         23
# 23     Biden +8         36
# 24     Biden +4         48
# 25     Biden +5         49
# 26   Sanders +3         45
# 27  Sanders +11         53
# 28   Sanders +5         55
# 29   Sanders +6         52
# 30  Sanders +12         46
# 31   Sanders +3         57
# 32  Sanders +13         51
# 33  Sanders +10         50
# 34   Sanders +9         55
# 35  Sanders +12         54
# 36   Sanders +9         55
# 37   Sanders +7         49
# 38   Sanders +6         58
# 39  Sanders +16         52
# 40  Sanders +12         58
# 41  Sanders +11         57
# 42  Sanders +11         53
# 43  Sanders +12         54
# 44   Sanders +3         59
# 45   Sanders +8         53
# 46   Sanders +4         60
# 47     Biden +3         57

# %%
# 7
# I know a lot of these codes are not outputting graphs because I recently updated my file and most of these 
# candidates have already dropped out
# But I kept the codes in here to prove that at one point they did work

def plotCandidate(candidate, file):
    plt.scatter(y=file[candidate], x=file["Poll"])

# %%
plotCandidate("Warren", democrat)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Warren'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-254e3620a2d5> in <module>
# ----> 1 plotCandidate("Warren", democrat)
#
# <ipython-input-37-4640bcfb03c6> in plotCandidate(candidate, file)
#       2
#       3 def plotCandidate(candidate, file):
# ----> 4     plt.scatter(y=file[candidate], x=file["Poll"])
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Warren'

# %%
plotCandidate("Buttigieg", democrat)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Buttigieg'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-4e445f11527a> in <module>
# ----> 1 plotCandidate("Buttigieg", democrat)
#
# <ipython-input-37-4640bcfb03c6> in plotCandidate(candidate, file)
#       2
#       3 def plotCandidate(candidate, file):
# ----> 4     plt.scatter(y=file[candidate], x=file["Poll"])
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Buttigieg'

# %%
plotCandidate("Sanders", democrat)

# %%
plotCandidate("Klobuchar", democrat)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Klobuchar'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-cc74067fbd25> in <module>
# ----> 1 plotCandidate("Klobuchar", democrat)
#
# <ipython-input-37-4640bcfb03c6> in plotCandidate(candidate, file)
#       2
#       3 def plotCandidate(candidate, file):
# ----> 4     plt.scatter(y=file[candidate], x=file["Poll"])
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Klobuchar'

# %%
plotCandidate("Steyer", democrat)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Steyer'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-ace4f2150bc3> in <module>
# ----> 1 plotCandidate("Steyer", democrat)
#
# <ipython-input-37-4640bcfb03c6> in plotCandidate(candidate, file)
#       2
#       3 def plotCandidate(candidate, file):
# ----> 4     plt.scatter(y=file[candidate], x=file["Poll"])
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Steyer'

# %%
plotCandidate("Bloomberg", democrat)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Bloomberg'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-a742074f6cd9> in <module>
# ----> 1 plotCandidate("Bloomberg", democrat)
#
# <ipython-input-37-4640bcfb03c6> in plotCandidate(candidate, file)
#       2
#       3 def plotCandidate(candidate, file):
# ----> 4     plt.scatter(y=file[candidate], x=file["Poll"])
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Bloomberg'

# %%
plotCandidate("Gabbard", democrat)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Gabbard'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-5a29ad97ec54> in <module>
# ----> 1 plotCandidate("Gabbard", democrat)
#
# <ipython-input-37-4640bcfb03c6> in plotCandidate(candidate, file)
#       2
#       3 def plotCandidate(candidate, file):
# ----> 4     plt.scatter(y=file[candidate], x=file["Poll"])
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Gabbard'

# %%
plotCandidate("Biden", democrat)

# %%
# 8 

def statsPerCandidate(candidate, file):
    averagePoll = file[candidate].mean()
    return averagePoll

# %%
# 9
statsPerCandidate("Sanders", democrat)
# Out:
# 31.1875

# %%
statsPerCandidate("Biden", democrat)
# Out:
# 36.9375

# %%
# the rest of the code for problem 9 will not run due to the fact that I just updated my file, however,
# I have decided to still include them

# %%
statsPerCandidate("Steyer", democrat)
statsPerCandidate("Warren", democrat)
statsPerCandidate("Buttigieg", democrat)
statsPerCandidate("Klobuchar", democrat)
statsPerCandidate("Bloomberg", democrat)
statsPerCandidate("Gabbard", democrat)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Steyer'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-116ed60f7ed5> in <module>
# ----> 1 statsPerCandidate("Steyer", democrat)
#       2 statsPerCandidate("Warren", democrat)
#       3 statsPerCandidate("Buttigieg", democrat)
#       4 statsPerCandidate("Klobuchar", democrat)
#       5 statsPerCandidate("Bloomberg", democrat)
#
# <ipython-input-48-92f105adbd53> in statsPerCandidate(candidate, file)
#       2
#       3 def statsPerCandidate(candidate, file):
# ----> 4     averagePoll = file[candidate].mean()
#       5     return averagePoll
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Steyer'

# %%
#10

def cleanSample(data):
    LV = []
    RV = []
    for i in data["Sample"]:
        LV.append(i[-2:])
        RV.append(i[:-2])
    for i in range(len(RV)):
        if RV[i] == '':
            RV[i] = 0
        else:
            RV[i] = int(RV[i])
    data["Sample Type"] = LV
    data["Sample Size"] = RV
    data = data.replace('', None)
    return data

# %%
#11

cleanSample(democrat)
# Out:
#                                 Poll         Date    Sample  Biden  Sanders  \
# 0             Economist/YouGovYouGov  3/29 - 3/31    573 LV     55       40
# 1           The Hill/HarrisXThe Hill  3/29 - 3/30    425 RV     54       32
# 2          Morning ConsultM. Consult  3/23 - 3/29  15101 RV     61       36
# 3               Harvard-HarrisHarris  3/24 - 3/26    903 RV     58       32
# 4           ABC News/Wash PostABC/WP  3/22 - 3/25    388 RV     55       39
# 5             Economist/YouGovYouGov  3/22 - 3/24    547 LV     57       39
# 6               Reuters/IpsosReuters  3/18 - 3/24   1981 RV     53       34
# 7          Morning ConsultM. Consult  3/16 - 3/22  16180 LV     60       36
# 8                     EmersonEmerson  3/18 - 3/19    519 RV     54       42
# 9             Economist/YouGovYouGov  3/15 - 3/17    551 LV     57       36
# 10              Reuters/IpsosReuters  3/13 - 3/16    458 RV     48       39
# 11          The Hill/HarrisXThe Hill  3/14 - 3/15    894 RV     55       31
# 12  Politico/Morning ConsultPolitico  3/11 - 3/15   8869 LV     58       37
# 13     NBC News/Wall St. JrnlNBC/WSJ  3/11 - 3/13    438 LV     61       32
# 14  Politico/Morning ConsultPolitico  3/11 - 3/11   2072 LV     59       35
# 15            Economist/YouGovYouGov   3/8 - 3/10    573 RV     53       38
# 16          The Hill/HarrisXThe Hill    3/8 - 3/9    442 RV     55       28
# 17              Reuters/IpsosReuters    3/6 - 3/9    420 RV     54       33
# 18              QuinnipiacQuinnipiac    3/5 - 3/8    559 RV     54       35
# 19  Politico/Morning ConsultPolitico    3/5 - 3/8   9593 RV     56       38
# 20                            CNNCNN    3/4 - 3/7    540 RV     52       36
# 21  Politico/Morning ConsultPolitico    3/5 - 3/5   1390 LV     54       38
# 22              Reuters/IpsosReuters    3/4 - 3/5    474 RV     45       32
# 23  Politico/Morning ConsultPolitico    3/2 - 3/3    961 LV     36       28
# 24            Economist/YouGovYouGov    3/1 - 3/3    722 RV     28       24
# 25          The Hill/HarrisXThe Hill    3/1 - 3/2    449 RV     28       23
# 26  Politico/Morning ConsultPolitico    3/1 - 3/1   2656 LV     26       29
# 27              Reuters/IpsosReuters   2/28 - 3/2    469 RV     18       29
# 28              Harvard-HarrisHarris  2/26 - 2/28    980 RV     20       25
# 29         Yahoo News/YouGov*YouGov*  2/26 - 2/27    811 RV     21       27
# 30  Politico/Morning ConsultPolitico  2/26 - 2/27   5334 LV     21       33
# 31                  IBD/TIPPIBD/TIPP  2/20 - 2/29    325 RV     20       23
# 32                  FOX NewsFOX News  2/23 - 2/26    507 LV     18       31
# 33            Economist/YouGovYouGov  2/23 - 2/25    584 RV     20       30
# 34          The Hill/HarrisXThe Hill  2/23 - 2/24    470 RV     17       28
# 35              Reuters/IpsosReuters  2/19 - 2/25   1808 RV     17       29
# 36           CBS News/YouGovCBS News  2/20 - 2/22   6498 LV     17       28
# 37                    EmersonEmerson  2/16 - 2/18    573 LV     22       29
# 38            Economist/YouGovYouGov  2/16 - 2/18    555 LV     18       24
# 39          ABC News/Wash PostABC/WP  2/14 - 2/17    408 RV     16       32
# 40     NBC News/Wall St. JrnlNBC/WSJ  2/14 - 2/17    426 LV     15       27
# 41              Reuters/IpsosReuters  2/14 - 2/17    385 RV     15       28
# 42                     SurveyUSASUSA  2/13 - 2/17   1022 LV     18       29
# 43             NPR/PBS/MaristNPR/PBS  2/13 - 2/16    527 RV     15       31
# 44          The Hill/HarrisXThe Hill  2/14 - 2/15    449 RV     19       22
# 45  Politico/Morning ConsultPolitico  2/12 - 2/17  15974 RV     19       28
# 46            Economist/YouGovYouGov   2/9 - 2/11    552 LV     18       22
# 47          The Hill/HarrisXThe Hill   2/7 - 2/10    913 RV     23       20
#
#          Spread Sample Type  Sample Size
# 0     Biden +15          LV          573
# 1     Biden +22          RV          425
# 2     Biden +25          RV        15101
# 3     Biden +26          RV          903
# 4     Biden +16          RV          388
# 5     Biden +18          LV          547
# 6     Biden +19          RV         1981
# 7     Biden +24          LV        16180
# 8     Biden +12          RV          519
# 9     Biden +21          LV          551
# 10     Biden +9          RV          458
# 11    Biden +24          RV          894
# 12    Biden +21          LV         8869
# 13    Biden +29          LV          438
# 14    Biden +24          LV         2072
# 15    Biden +15          RV          573
# 16    Biden +27          RV          442
# 17    Biden +21          RV          420
# 18    Biden +19          RV          559
# 19    Biden +18          RV         9593
# 20    Biden +16          RV          540
# 21    Biden +16          LV         1390
# 22    Biden +13          RV          474
# 23     Biden +8          LV          961
# 24     Biden +4          RV          722
# 25     Biden +5          RV          449
# 26   Sanders +3          LV         2656
# 27  Sanders +11          RV          469
# 28   Sanders +5          RV          980
# 29   Sanders +6          RV          811
# 30  Sanders +12          LV         5334
# 31   Sanders +3          RV          325
# 32  Sanders +13          LV          507
# 33  Sanders +10          RV          584
# 34   Sanders +9          RV          470
# 35  Sanders +12          RV         1808
# 36   Sanders +9          LV         6498
# 37   Sanders +7          LV          573
# 38   Sanders +6          LV          555
# 39  Sanders +16          RV          408
# 40  Sanders +12          LV          426
# 41  Sanders +11          RV          385
# 42  Sanders +11          LV         1022
# 43  Sanders +12          RV          527
# 44   Sanders +3          RV          449
# 45   Sanders +8          RV        15974
# 46   Sanders +4          LV          552
# 47     Biden +3          RV          913

# %%
#12

def computePollWeight(data, pollName):
    return sum(data[data['Poll'] == pollName]["Sample Size"]) / sum(data["Sample Size"])

# %%
computePollWeight(democrat, "Morning ConsultM. Consult")
# Out:
# 0.28897531594117215

# %%
computePollWeight(democrat, "Politico/Morning ConsultPolitico")
# Out:
# 0.4327932155790407

# %%
computePollWeight(democrat, "Reuters/IpsosReuters")
# Out:
# 0.05538208558125785

# %%
#13

def weightedStatsPerCandidate(candidate, df):
    weight = []
    for poll in df["Poll"].unique():
        x = sum(df[df["Poll"] == poll][candidate])
        y = computePollWeight(df, poll)
        weight.append(x*y)
    return sum(weight)/len(weight)

# %%
#14
weightedStatsPerCandidate("Biden", democrat)
# Out:
# 12.887830559021333

# %%
weightedStatsPerCandidate("Sanders", democrat)
# Out:
# 10.098413990531546

# %%
# Based on the calculations that I have made above, I believe that Joe Biden is slightly
# more likely to win the nomination over Bernie Sanders

# %%
# 15

def computeCorrelation(candidate1, candidate2, file):
    return file[candidate1].corr(file[candidate2])

# %%
#16 

myCandidate = []
repeat = []

for candidate1 in myCandidate:
    for candidate2 in myCandidate:
        if candidate1 != candidate2:
            if [candidate1, candidate2] not in repeat and [candidate1, candidate2] not in repeat:
                print(candidate1 + "vs" + candidate2 + ": " + computeCorrelation(candidate1, candidate2, file))
                repeat.append([candidate1, candidate2])

# %%
print(computeCorrelation("Biden", "Sanders", democrat))
# Out:
# 0.7381404992868207

# %%
# Unfortunatley, due to the fact that I just updated my data file, Biden and Sanders are the only two 
# candidates that are left in the race. However, I ran the Correlation function with both of them and 
# I came out with a score of 0.738, which indicates there may be some correlation between the two (not too much)

# %%
#17

def superTuesday(file, candidates):
    BidenST = []
    SandersST = []
    
    for i, row in file.iterrows():
        Biden = row["Biden"]
        Sanders = row["Sanders"]
        for candidate in candidates:
            if candidate != "Biden" and candidate != "Sanders":
                BidenC = computeCorrelation("Biden", candidate, file)
                SandersC = computeCorrelation("Sanders", candidate, file)
                if abs(BidenC) > abs(SandersC):
                    Biden += row[candidate]
                else:
                    Sander += row[candidate]
            BidenST.append(BidenC)
            SandersST.append(SandersC)
    file["BidenST"] = BidenST
    file["SandersST"] = SandersST

# %%
#18

superTuesday(democrat, myCandidate)
print("Sanders mean is", int(democrat["SandersST"].mean()))
print("Bidens mean is", int(democrat["BidenST"].mean()))
print("Sanders weighted mean is", int(weightedStatsPerCandidate("Sanders", democrat)))
print("Bidens weighted mean is", int(weightedStatsPerCandidate("Biden", democrat)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-114-dbbe09dd664e> in <module>
#       1 #18
#       2
# ----> 3 superTuesday(democrat, myCandidate)
#       4 print("Sanders mean is", int(democrat["SandersST"].mean()))
#       5 print("Bidens mean is", int(democrat["BidenST"].mean()))
#
# <ipython-input-113-5dfd3e84dad4> in superTuesday(file, candidates)
#      18             BidenST.append(BidenC)
#      19             SandersST.append(SandersC)
# ---> 20     file["BidenST"] = BidenST
#      21     file["SandersST"] = SandersST
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# -> 3445         value = self._sanitize_column(key, value)
#    3446         NDFrame._set_item(self, key, value)
#    3447
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3628
#    3629             # turn me into an ndarray
# -> 3630             value = sanitize_index(value, self.index, copy=False)
#    3631             if not isinstance(value, (np.ndarray, Index)):
#    3632                 if isinstance(value, list) and len(value) > 0:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals/construction.py in sanitize_index(data, index, copy)
#     517
#     518     if len(data) != len(index):
# --> 519         raise ValueError('Length of values does not match length of index')
#     520
#     521     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %%
import numpy as np
import scipy.stats

# %%
# 19
def getConfidenceInterval(datacolumn):
    npArray = 1.0 * np.array(datacolumn)
    stdErr = scipy.stats.sem(npArray)
    n = len(datacolumn)
    return stdErr * scipy.stats.t.ppf((1 + .95)/2.0, n-1)

# %%
getConfidenceInterval(democrat["Biden"])
# Out:
# 5.273265589613979

# %%
getConfidenceInterval(democrat["Sanders"])
# Out:
# 1.5741582315245837

# %%
# 20
def runTTest(data1, data2):
    return scipy.stats.ttest_ind(data1, data2)

# %%
print(runTTest(democrat["Biden"], democrat["Sanders"]))
print(runTTest(democrat["BidenST"], democrat["SandersST"]))
# Out:
# Ttest_indResult(statistic=2.101957044465843, pvalue=0.03823096545712006)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'BidenST'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-125-8fbed139f129> in <module>
#       1 print(runTTest(democrat["Biden"], democrat["Sanders"]))
# ----> 2 print(runTTest(democrat["BidenST"], democrat["SandersST"]))
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'BidenST'
